# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Create an empty list to hold weather data for each city
city_data = []

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 90) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
x = 1
lonitude = []
while x < 11:
    random_lngs = random.randint(-180, 180) + random.random()
    latitudes.append(random_lat)
    x += 1

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = []

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for lat_lng in lat_lngs:
    # Use the citipy module to identify the nearest city to the current coordinate
    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=663bc986e0f24e968eb8e5e84d5aebbb

# %%
city_url = url + "&q=" + cities[4].replace(" ","+")
city_weather = requests.get(city_url).json()
city_lng = city_weather["coord"]["lon"]
city_lng
# Out:
# -134.9692

# %%
# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Country": city_country})
    
    # If an error is experienced, skip the city
    except Exception as e:
        print(e)
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | san lorenzo
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | lodja
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | kampene
# Processing Record 9 of Set 1 | belushya guba
# 'coord'
# Processing Record 10 of Set 1 | faya
# Processing Record 11 of Set 1 | ballinrobe
# Processing Record 12 of Set 1 | sentyabrskiy
# 'coord'
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | hami
# Processing Record 21 of Set 1 | asau
# Processing Record 22 of Set 1 | sao filipe
# Processing Record 23 of Set 1 | kuche
# 'coord'
# Processing Record 24 of Set 1 | waipawa
# Processing Record 25 of Set 1 | vardo
# Processing Record 26 of Set 1 | port lincoln
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | sorvag
# 'coord'
# Processing Record 30 of Set 1 | aktash
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | sydney
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | srednekolymsk
# Processing Record 35 of Set 1 | xuddur
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | roald
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | quatre cocos
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | bosaso
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | taolanaro
# 'coord'
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | paamiut
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | alta floresta
# Processing Record 5 of Set 2 | mount gambier
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | gouyave
# Processing Record 8 of Set 2 | palabuhanratu
# 'coord'
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | shiraoi
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | ampanihy
# Processing Record 13 of Set 2 | oxelosund
# Processing Record 14 of Set 2 | plettenberg bay
# Processing Record 15 of Set 2 | tottori
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | lavrentiya
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | punta arenas
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | uvinza
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | kinablangan
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | kondinskoye
# Processing Record 30 of Set 2 | parabel
# Processing Record 31 of Set 2 | baruun-urt
# Processing Record 32 of Set 2 | attawapiskat
# 'coord'
# Processing Record 33 of Set 2 | macas
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | zinder
# Processing Record 36 of Set 2 | skalistyy
# 'coord'
# Processing Record 37 of Set 2 | saint-pierre
# Processing Record 38 of Set 2 | kurmanayevka
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | dali
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | balkanabat
# Processing Record 45 of Set 2 | narsaq
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | san quintin
# Processing Record 49 of Set 2 | shirokiy
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | half moon bay
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | morondava
# Processing Record 4 of Set 3 | gat
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | nyrob
# Processing Record 7 of Set 3 | kiunga
# Processing Record 8 of Set 3 | sinnamary
# Processing Record 9 of Set 3 | umm lajj
# Processing Record 10 of Set 3 | martil
# Processing Record 11 of Set 3 | san jose
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | urucui
# Processing Record 14 of Set 3 | marsabit
# Processing Record 15 of Set 3 | krasnoborsk
# Processing Record 16 of Set 3 | zeitz
# Processing Record 17 of Set 3 | boa viagem
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | marsaxlokk
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | saint-leu
# Processing Record 22 of Set 3 | acapulco
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | nampula
# Processing Record 27 of Set 3 | esna
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | kamenka
# Processing Record 30 of Set 3 | mehran
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | hobyo
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | tumannyy
# 'coord'
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | peniche
# Processing Record 38 of Set 3 | chaihe
# Processing Record 39 of Set 3 | mys shmidta
# 'coord'
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | banjar
# Processing Record 42 of Set 3 | tautira
# Processing Record 43 of Set 3 | golubitskaya
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | qaanaaq
# Processing Record 48 of Set 3 | nizhneyansk
# 'coord'
# Processing Record 49 of Set 3 | fort-shevchenko
# Processing Record 50 of Set 3 | yuzhno-kurilsk
# Processing Record 1 of Set 4 | panama city
# Processing Record 2 of Set 4 | kijang
# Processing Record 3 of Set 4 | rungata
# 'coord'
# Processing Record 4 of Set 4 | belaya gora
# Processing Record 5 of Set 4 | port augusta
# Processing Record 6 of Set 4 | bargal
# 'coord'
# Processing Record 7 of Set 4 | oxbow
# Processing Record 8 of Set 4 | aleksandrovsk-sakhalinskiy
# Processing Record 9 of Set 4 | ulaanbaatar
# Processing Record 10 of Set 4 | barentsburg
# 'coord'
# Processing Record 11 of Set 4 | araouane
# Processing Record 12 of Set 4 | warqla
# 'coord'
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | kalmunai
# Processing Record 15 of Set 4 | cockburn town
# Processing Record 16 of Set 4 | grand river south east
# 'coord'
# Processing Record 17 of Set 4 | imperatriz
# Processing Record 18 of Set 4 | ahipara
# Processing Record 19 of Set 4 | agogo
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | marcona
# 'coord'
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | saint andrews
# Processing Record 25 of Set 4 | angahuan
# Processing Record 26 of Set 4 | illoqqortoormiut
# 'coord'
# Processing Record 27 of Set 4 | bafq
# Processing Record 28 of Set 4 | brokopondo
# Processing Record 29 of Set 4 | talnakh
# Processing Record 30 of Set 4 | sur
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | concarneau
# Processing Record 33 of Set 4 | nova floresta
# Processing Record 34 of Set 4 | hermanus
# Processing Record 35 of Set 4 | havelock
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | sao joao da barra
# Processing Record 38 of Set 4 | rocha
# Processing Record 39 of Set 4 | velsk
# Processing Record 40 of Set 4 | makakilo city
# Processing Record 41 of Set 4 | eydhafushi
# Processing Record 42 of Set 4 | jalingo
# Processing Record 43 of Set 4 | bezhetsk
# Processing Record 44 of Set 4 | buqayq
# 'coord'
# Processing Record 45 of Set 4 | verkhnyachka
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | noumea
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | tomatlan
# Processing Record 1 of Set 5 | isabela
# Processing Record 2 of Set 5 | patos
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | bilma
# Processing Record 5 of Set 5 | ketchikan
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | tazovskiy
# Processing Record 8 of Set 5 | ondjiva
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | buala
# Processing Record 11 of Set 5 | coahuayana
# Processing Record 12 of Set 5 | naruja
# Processing Record 13 of Set 5 | wajima
# Processing Record 14 of Set 5 | canatlan
# Processing Record 15 of Set 5 | columbia
# Processing Record 16 of Set 5 | deshna
# 'coord'
# Processing Record 17 of Set 5 | anadyr
# Processing Record 18 of Set 5 | ngukurr
# 'coord'
# Processing Record 19 of Set 5 | pervomayskiy
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | carlos antonio lopez
# Processing Record 22 of Set 5 | kayankulam
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | launceston
# Processing Record 25 of Set 5 | chunar
# Processing Record 26 of Set 5 | suntar
# Processing Record 27 of Set 5 | bokajan
# Processing Record 28 of Set 5 | storforshei
# Processing Record 29 of Set 5 | dabakala
# Processing Record 30 of Set 5 | platanos
# Processing Record 31 of Set 5 | ulladulla
# Processing Record 32 of Set 5 | mettet
# Processing Record 33 of Set 5 | kokoda
# Processing Record 34 of Set 5 | odesskoye
# Processing Record 35 of Set 5 | quchan
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | huarmey
# Processing Record 38 of Set 5 | nanortalik
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | cabo rojo
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | mackay
# Processing Record 43 of Set 5 | nome
# Processing Record 44 of Set 5 | north bend
# Processing Record 45 of Set 5 | kiruna
# Processing Record 46 of Set 5 | sumbawa
# 'coord'
# Processing Record 47 of Set 5 | bandar maharani
# 'coord'
# Processing Record 48 of Set 5 | lindi
# Processing Record 49 of Set 5 | jacqueville
# Processing Record 50 of Set 5 | chelno-vershiny
# Processing Record 1 of Set 6 | port elizabeth
# Processing Record 2 of Set 6 | iskateley
# Processing Record 3 of Set 6 | el faiyum
# 'coord'
# Processing Record 4 of Set 6 | numan
# Processing Record 5 of Set 6 | nyurba
# Processing Record 6 of Set 6 | ibra
# Processing Record 7 of Set 6 | saleaula
# 'coord'
# Processing Record 8 of Set 6 | labuan
# Processing Record 9 of Set 6 | comodoro rivadavia
# Processing Record 10 of Set 6 | roma
# Processing Record 11 of Set 6 | zemio
# Processing Record 12 of Set 6 | aklavik
# Processing Record 13 of Set 6 | henties bay
# Processing Record 14 of Set 6 | kerouane
# Processing Record 15 of Set 6 | hvammstangi
# 'coord'
# Processing Record 16 of Set 6 | kozhevnikovo
# Processing Record 17 of Set 6 | kurilsk
# Processing Record 18 of Set 6 | muktagachha
# 'coord'
# Processing Record 19 of Set 6 | amantea
# Processing Record 20 of Set 6 | rockport
# Processing Record 21 of Set 6 | samusu
# 'coord'
# Processing Record 22 of Set 6 | jose de freitas
# Processing Record 23 of Set 6 | impfondo
# Processing Record 24 of Set 6 | benjamin constant
# Processing Record 25 of Set 6 | leiyang
# Processing Record 26 of Set 6 | payo
# Processing Record 27 of Set 6 | dhidhdhoo
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | matay
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | marv dasht
# 'coord'
# Processing Record 32 of Set 6 | grindavik
# Processing Record 33 of Set 6 | namibe
# Processing Record 34 of Set 6 | bonavista
# Processing Record 35 of Set 6 | sete lagoas
# Processing Record 36 of Set 6 | monroe
# Processing Record 37 of Set 6 | birjand
# Processing Record 38 of Set 6 | bayeux
# Processing Record 39 of Set 6 | korla
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | morro bay
# Processing Record 42 of Set 6 | candawaga
# 'coord'
# Processing Record 43 of Set 6 | neiafu
# Processing Record 44 of Set 6 | bow island
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | amderma
# 'coord'
# Processing Record 47 of Set 6 | pacific grove
# Processing Record 48 of Set 6 | tilichiki
# Processing Record 49 of Set 6 | balaguer
# Processing Record 50 of Set 6 | dera gopipur
# Processing Record 1 of Set 7 | blind river
# Processing Record 2 of Set 7 | hokitika
# Processing Record 3 of Set 7 | qurbah
# 'coord'
# Processing Record 4 of Set 7 | kirakira
# Processing Record 5 of Set 7 | beringovskiy
# Processing Record 6 of Set 7 | nueve de julio
# Processing Record 7 of Set 7 | zemen
# Processing Record 8 of Set 7 | kudahuvadhoo
# Processing Record 9 of Set 7 | mareeba
# Processing Record 10 of Set 7 | bilibino
# Processing Record 11 of Set 7 | cayenne
# Processing Record 12 of Set 7 | kaabong
# Processing Record 13 of Set 7 | la plata
# Processing Record 14 of Set 7 | xingcheng
# Processing Record 15 of Set 7 | kegayli
# 'coord'
# Processing Record 16 of Set 7 | buraydah
# Processing Record 17 of Set 7 | verkhnyaya inta
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | sisimiut
# Processing Record 20 of Set 7 | shingu
# Processing Record 21 of Set 7 | hofn
# Processing Record 22 of Set 7 | bajil
# Processing Record 23 of Set 7 | mahebourg
# Processing Record 24 of Set 7 | saravan
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | luderitz
# Processing Record 27 of Set 7 | hellin
# Processing Record 28 of Set 7 | burica
# 'coord'
# Processing Record 29 of Set 7 | baykit
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | den helder
# Processing Record 32 of Set 7 | ambrolauri
# Processing Record 33 of Set 7 | kuminskiy
# Processing Record 34 of Set 7 | phuket
# Processing Record 35 of Set 7 | oum hadjer
# Processing Record 36 of Set 7 | leamington
# Processing Record 37 of Set 7 | kaeo
# Processing Record 38 of Set 7 | leopold
# Processing Record 39 of Set 7 | sumbe
# Processing Record 40 of Set 7 | devils lake
# Processing Record 41 of Set 7 | shushtar
# Processing Record 42 of Set 7 | vestmannaeyjar
# Processing Record 43 of Set 7 | hambantota
# Processing Record 44 of Set 7 | lasa
# Processing Record 45 of Set 7 | logrono
# Processing Record 46 of Set 7 | yar-sale
# Processing Record 47 of Set 7 | clyde river
# Processing Record 48 of Set 7 | lolua
# 'coord'
# Processing Record 49 of Set 7 | ndioum
# Processing Record 50 of Set 7 | ischia
# Processing Record 1 of Set 8 | shaoyang
# Processing Record 2 of Set 8 | otavi
# Processing Record 3 of Set 8 | kangaatsiaq
# Processing Record 4 of Set 8 | olavarria
# Processing Record 5 of Set 8 | marzuq
# Processing Record 6 of Set 8 | shizukuishi
# Processing Record 7 of Set 8 | nhulunbuy
# Processing Record 8 of Set 8 | isangel
# Processing Record 9 of Set 8 | karamay
# 'coord'
# Processing Record 10 of Set 8 | mandalgovi
# Processing Record 11 of Set 8 | ostersund
# Processing Record 12 of Set 8 | mahibadhoo
# Processing Record 13 of Set 8 | angoche
# Processing Record 14 of Set 8 | chinhoyi
# Processing Record 15 of Set 8 | luau
# Processing Record 16 of Set 8 | mongu
# Processing Record 17 of Set 8 | tarazona
# Processing Record 18 of Set 8 | guariba
# Processing Record 19 of Set 8 | jinchengjiang
# 'coord'
# Processing Record 20 of Set 8 | sept-iles
# Processing Record 21 of Set 8 | bruck an der leitha
# Processing Record 22 of Set 8 | mount pleasant
# Processing Record 23 of Set 8 | karratha
# Processing Record 24 of Set 8 | troitskoye
# Processing Record 25 of Set 8 | harper
# Processing Record 26 of Set 8 | lorengau
# Processing Record 27 of Set 8 | warrnambool
# Processing Record 28 of Set 8 | buariki
# 'coord'
# Processing Record 29 of Set 8 | pahrump
# Processing Record 30 of Set 8 | nova granada
# Processing Record 31 of Set 8 | dinar
# Processing Record 32 of Set 8 | bossembele
# 'coord'
# Processing Record 33 of Set 8 | grand gaube
# Processing Record 34 of Set 8 | broken hill
# Processing Record 35 of Set 8 | nuuk
# Processing Record 36 of Set 8 | limbe
# Processing Record 37 of Set 8 | maragogi
# Processing Record 38 of Set 8 | bethanien
# Processing Record 39 of Set 8 | hede
# Processing Record 40 of Set 8 | fomboni
# Processing Record 41 of Set 8 | grand forks
# Processing Record 42 of Set 8 | bubaque
# Processing Record 43 of Set 8 | nishihara
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | caravelas
# Processing Record 46 of Set 8 | xadani
# 'coord'
# Processing Record 47 of Set 8 | kathmandu
# Processing Record 48 of Set 8 | kapoeta
# Processing Record 49 of Set 8 | pierre
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | keti bandar
# Processing Record 2 of Set 9 | yeppoon
# Processing Record 3 of Set 9 | inverness
# Processing Record 4 of Set 9 | staryy nadym
# Processing Record 5 of Set 9 | mahon
# Processing Record 6 of Set 9 | pilar
# Processing Record 7 of Set 9 | lamesa
# Processing Record 8 of Set 9 | iquique
# Processing Record 9 of Set 9 | dehloran
# Processing Record 10 of Set 9 | waddan
# Processing Record 11 of Set 9 | labutta
# 'coord'
# Processing Record 12 of Set 9 | shimoda
# Processing Record 13 of Set 9 | yatou
# Processing Record 14 of Set 9 | pombas
# Processing Record 15 of Set 9 | nantucket
# Processing Record 16 of Set 9 | maniitsoq
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | khandbari
# Processing Record 19 of Set 9 | toliary
# 'coord'
# Processing Record 20 of Set 9 | carupano
# Processing Record 21 of Set 9 | vaitupu
# 'coord'
# Processing Record 22 of Set 9 | nouadhibou
# Processing Record 23 of Set 9 | osakarovka
# Processing Record 24 of Set 9 | urfa
# 'coord'
# Processing Record 25 of Set 9 | axim
# Processing Record 26 of Set 9 | robertsport
# Processing Record 27 of Set 9 | langnau
# Processing Record 28 of Set 9 | balili
# Processing Record 29 of Set 9 | bodden town
# Processing Record 30 of Set 9 | moose factory
# Processing Record 31 of Set 9 | santa cruz de la palma
# Processing Record 32 of Set 9 | key largo
# Processing Record 33 of Set 9 | rawlins
# Processing Record 34 of Set 9 | roebourne
# Processing Record 35 of Set 9 | port moresby
# Processing Record 36 of Set 9 | zeya
# Processing Record 37 of Set 9 | hornepayne
# Processing Record 38 of Set 9 | binzhou
# Processing Record 39 of Set 9 | qasigiannguit
# Processing Record 40 of Set 9 | ilhabela
# Processing Record 41 of Set 9 | delijan
# Processing Record 42 of Set 9 | stryn
# Processing Record 43 of Set 9 | godda
# Processing Record 44 of Set 9 | skjervoy
# Processing Record 45 of Set 9 | piacabucu
# Processing Record 46 of Set 9 | port-cartier
# Processing Record 47 of Set 9 | monmouth
# Processing Record 48 of Set 9 | fort nelson
# Processing Record 49 of Set 9 | felanitx
# Processing Record 50 of Set 9 | tateyama
# Processing Record 1 of Set 10 | kesennuma
# 'coord'
# Processing Record 2 of Set 10 | lakes entrance
# Processing Record 3 of Set 10 | uyuni
# Processing Record 4 of Set 10 | fevralsk
# 'coord'
# Processing Record 5 of Set 10 | banikoara
# Processing Record 6 of Set 10 | necochea
# Processing Record 7 of Set 10 | sola
# Processing Record 8 of Set 10 | stornoway
# Processing Record 9 of Set 10 | bystryy istok
# Processing Record 10 of Set 10 | college
# Processing Record 11 of Set 10 | panjakent
# Processing Record 12 of Set 10 | osorheiu
# Processing Record 13 of Set 10 | santa isabel
# Processing Record 14 of Set 10 | taksimo
# Processing Record 15 of Set 10 | esso
# Processing Record 16 of Set 10 | idil
# Processing Record 17 of Set 10 | rincon de la victoria
# Processing Record 18 of Set 10 | lipin bor
# Processing Record 19 of Set 10 | shelburne
# Processing Record 20 of Set 10 | pangai
# Processing Record 21 of Set 10 | castano primo
# Processing Record 22 of Set 10 | kjellerup
# Processing Record 23 of Set 10 | airai
# Processing Record 24 of Set 10 | rabagani
# Processing Record 25 of Set 10 | coquimbo
# Processing Record 26 of Set 10 | camabatela
# Processing Record 27 of Set 10 | narimanov
# Processing Record 28 of Set 10 | ancud
# Processing Record 29 of Set 10 | san cristobal
# Processing Record 30 of Set 10 | meulaboh
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | la ronge
# Processing Record 33 of Set 10 | sokoni
# Processing Record 34 of Set 10 | isahaya
# Processing Record 35 of Set 10 | le havre
# Processing Record 36 of Set 10 | amahai
# Processing Record 37 of Set 10 | houlton
# Processing Record 38 of Set 10 | kamphaeng phet
# Processing Record 39 of Set 10 | kilindoni
# Processing Record 40 of Set 10 | vanavara
# Processing Record 41 of Set 10 | jennings
# Processing Record 42 of Set 10 | esmeralda
# Processing Record 43 of Set 10 | umzimvubu
# 'coord'
# Processing Record 44 of Set 10 | yumen
# Processing Record 45 of Set 10 | dinsor
# 'coord'
# Processing Record 46 of Set 10 | marrakesh
# Processing Record 47 of Set 10 | bonito
# Processing Record 48 of Set 10 | mayachnyy
# Processing Record 49 of Set 10 | zhezkazgan
# Processing Record 50 of Set 10 | ormara
# Processing Record 1 of Set 11 | cabinda
# Processing Record 2 of Set 11 | tigil
# Processing Record 3 of Set 11 | corinto
# Processing Record 4 of Set 11 | palmer
# Processing Record 5 of Set 11 | high level
# Processing Record 6 of Set 11 | shenzhen
# Processing Record 7 of Set 11 | cabedelo
# Processing Record 8 of Set 11 | richards bay
# Processing Record 9 of Set 11 | ballina
# Processing Record 10 of Set 11 | coueron
# Processing Record 11 of Set 11 | san rafael
# Processing Record 12 of Set 11 | marsh harbour
# Processing Record 13 of Set 11 | vreed en hoop
# 'coord'
# Processing Record 14 of Set 11 | marsa matruh
# Processing Record 15 of Set 11 | gizo
# Processing Record 16 of Set 11 | puerto cabezas
# Processing Record 17 of Set 11 | sudak
# Processing Record 18 of Set 11 | saint-francois
# Processing Record 19 of Set 11 | namatanai
# Processing Record 20 of Set 11 | weiser
# Processing Record 21 of Set 11 | pitimbu
# Processing Record 22 of Set 11 | penticton
# Processing Record 23 of Set 11 | muyezerskiy
# Processing Record 24 of Set 11 | aksum
# Processing Record 25 of Set 11 | hasaki
# Processing Record 26 of Set 11 | sistranda
# Processing Record 27 of Set 11 | ambilobe
# Processing Record 28 of Set 11 | walvis bay
# Processing Record 29 of Set 11 | yerbogachen
# Processing Record 30 of Set 11 | riyadh
# Processing Record 31 of Set 11 | nuevo progreso
# Processing Record 32 of Set 11 | berlevag
# Processing Record 33 of Set 11 | avera
# Processing Record 34 of Set 11 | mbigou
# Processing Record 35 of Set 11 | saint-denis
# Processing Record 36 of Set 11 | butembo
# Processing Record 37 of Set 11 | goderich
# Processing Record 38 of Set 11 | rapina
# Processing Record 39 of Set 11 | zabol
# Processing Record 40 of Set 11 | north branch
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | ambon
# Processing Record 43 of Set 11 | baker city
# Processing Record 44 of Set 11 | krasne
# Processing Record 45 of Set 11 | matamoros
# Processing Record 46 of Set 11 | curup
# Processing Record 47 of Set 11 | karasjok
# Processing Record 48 of Set 11 | conakry
# Processing Record 49 of Set 11 | filadelfia
# Processing Record 50 of Set 11 | khonuu
# 'coord'
# Processing Record 1 of Set 12 | oussouye
# Processing Record 2 of Set 12 | port keats
# Processing Record 3 of Set 12 | akyab
# Processing Record 4 of Set 12 | tobermory
# Processing Record 5 of Set 12 | los llanos de aridane
# Processing Record 6 of Set 12 | olbia
# Processing Record 7 of Set 12 | crema
# Processing Record 8 of Set 12 | alabaster
# Processing Record 9 of Set 12 | grand centre
# 'coord'
# Processing Record 10 of Set 12 | broome
# Processing Record 11 of Set 12 | ajaccio
# Processing Record 12 of Set 12 | yulara
# Processing Record 13 of Set 12 | tura
# Processing Record 14 of Set 12 | takoradi
# Processing Record 15 of Set 12 | kamina
# Processing Record 16 of Set 12 | matara
# Processing Record 17 of Set 12 | kinkala
# Processing Record 18 of Set 12 | unity
# Processing Record 19 of Set 12 | morant bay
# Processing Record 20 of Set 12 | beyneu
# Processing Record 21 of Set 12 | vila franca do campo
# Processing Record 22 of Set 12 | malatya
# Processing Record 23 of Set 12 | dawson creek
# Processing Record 24 of Set 12 | felidhoo
# 'coord'
# Processing Record 25 of Set 12 | ayna
# Processing Record 26 of Set 12 | kambove
# Processing Record 27 of Set 12 | buluang
# Processing Record 28 of Set 12 | qui nhon
# Processing Record 29 of Set 12 | sogdiondon
# 'coord'
# Processing Record 30 of Set 12 | dolbeau
# 'coord'
# Processing Record 31 of Set 12 | tres arroyos
# Processing Record 32 of Set 12 | selikhino
# Processing Record 33 of Set 12 | mehamn
# Processing Record 34 of Set 12 | kovdor
# Processing Record 35 of Set 12 | nanuque
# Processing Record 36 of Set 12 | ruidoso
# Processing Record 37 of Set 12 | nongpoh
# Processing Record 38 of Set 12 | progreso
# Processing Record 39 of Set 12 | el chol
# Processing Record 40 of Set 12 | katherine
# Processing Record 41 of Set 12 | gejiu
# Processing Record 42 of Set 12 | tsihombe
# 'coord'
# Processing Record 43 of Set 12 | saint anthony
# Processing Record 44 of Set 12 | atikokan
# Processing Record 45 of Set 12 | panorama
# Processing Record 46 of Set 12 | lubsko
# Processing Record 47 of Set 12 | vega de alatorre
# Processing Record 48 of Set 12 | nha trang
# Processing Record 49 of Set 12 | sawtell
# Processing Record 50 of Set 12 | la romana
# Processing Record 1 of Set 13 | wucheng
# Processing Record 2 of Set 13 | bacuit
# 'coord'
# Processing Record 3 of Set 13 | bandar-e torkaman
# 'coord'
# Processing Record 4 of Set 13 | arraial do cabo
# Processing Record 5 of Set 13 | forbach
# Processing Record 6 of Set 13 | pauini
# Processing Record 7 of Set 13 | zabaykalsk
# Processing Record 8 of Set 13 | agirish
# Processing Record 9 of Set 13 | bahraich
# Processing Record 10 of Set 13 | pusad
# Processing Record 11 of Set 13 | lavumisa
# Processing Record 12 of Set 13 | nortelandia
# Processing Record 13 of Set 13 | sabang
# Processing Record 14 of Set 13 | buenavista
# Processing Record 15 of Set 13 | abbeville
# Processing Record 16 of Set 13 | bac lieu
# Processing Record 17 of Set 13 | pangkalanbuun
# Processing Record 18 of Set 13 | barra patuca
# Processing Record 19 of Set 13 | nichinan
# Processing Record 20 of Set 13 | salalah
# Processing Record 21 of Set 13 | benghazi
# Processing Record 22 of Set 13 | litoral del san juan
# 'coord'
# Processing Record 23 of Set 13 | bagdarin
# Processing Record 24 of Set 13 | kieta
# Processing Record 25 of Set 13 | samarai
# Processing Record 26 of Set 13 | chivay
# Processing Record 27 of Set 13 | vao
# Processing Record 28 of Set 13 | acajutla
# Processing Record 29 of Set 13 | maputo
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Processing Record 30 of Set 13 | kasane
# Processing Record 31 of Set 13 | nalut
# Processing Record 32 of Set 13 | tarauaca
# Processing Record 33 of Set 13 | dauphin
# Processing Record 34 of Set 13 | vanderhoof
# Processing Record 35 of Set 13 | america dourada
# Processing Record 36 of Set 13 | kenai
# Processing Record 37 of Set 13 | syntul
# Processing Record 38 of Set 13 | ola
# Processing Record 39 of Set 13 | jizan
# Processing Record 40 of Set 13 | balikpapan
# Processing Record 41 of Set 13 | kushiro
# Processing Record 42 of Set 13 | hit
# Processing Record 43 of Set 13 | abatskoye
# Processing Record 44 of Set 13 | moroto
# Processing Record 45 of Set 13 | santa isabel do rio negro
# Processing Record 46 of Set 13 | pachino
# Processing Record 47 of Set 13 | tikrit
# Processing Record 48 of Set 13 | moses lake
# Processing Record 49 of Set 13 | atbasar
# Processing Record 50 of Set 13 | ust-kamchatsk
# 'coord'
# Processing Record 1 of Set 14 | mitsamiouli
# Processing Record 2 of Set 14 | severo-yeniseyskiy
# Processing Record 3 of Set 14 | lae
# Processing Record 4 of Set 14 | kayerkan
# Processing Record 5 of Set 14 | raymond
# Processing Record 6 of Set 14 | williston
# Processing Record 7 of Set 14 | torremolinos
# Processing Record 8 of Set 14 | ocean city
# Processing Record 9 of Set 14 | havoysund
# Processing Record 10 of Set 14 | chicama
# Processing Record 11 of Set 14 | bluffton
# Processing Record 12 of Set 14 | powell
# Processing Record 13 of Set 14 | zhanatas
# 'coord'
# Processing Record 14 of Set 14 | laizhou
# Processing Record 15 of Set 14 | bathsheba
# Processing Record 16 of Set 14 | port blair
# Processing Record 17 of Set 14 | ziway
# Processing Record 18 of Set 14 | port jervis
# Processing Record 19 of Set 14 | honda
# Processing Record 20 of Set 14 | fukuma
# Processing Record 21 of Set 14 | petropavlovka
# Processing Record 22 of Set 14 | kernersville
# Processing Record 23 of Set 14 | lamu
# Processing Record 24 of Set 14 | svetlogorsk
# Processing Record 25 of Set 14 | trairi
# Processing Record 26 of Set 14 | sambava
# Processing Record 27 of Set 14 | maloshuyka
# 'coord'
# Processing Record 28 of Set 14 | wawa
# Processing Record 29 of Set 14 | bemidji
# Processing Record 30 of Set 14 | sakaraha
# Processing Record 31 of Set 14 | kaputa
# Processing Record 32 of Set 14 | otavalo
# Processing Record 33 of Set 14 | sao jose da coroa grande
# Processing Record 34 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 14 | mtwara
# Processing Record 36 of Set 14 | lac du bonnet
# Processing Record 37 of Set 14 | abu kamal
# Processing Record 38 of Set 14 | haines junction
# Processing Record 39 of Set 14 | melioratorov
# Processing Record 40 of Set 14 | cap malheureux
# Processing Record 41 of Set 14 | katobu
# Processing Record 42 of Set 14 | touho
# Processing Record 43 of Set 14 | frankfort
# Processing Record 44 of Set 14 | klaksvik
# Processing Record 45 of Set 14 | vanimo
# Processing Record 46 of Set 14 | marawi
# Processing Record 47 of Set 14 | kahului
# Processing Record 48 of Set 14 | hualmay
# Processing Record 49 of Set 14 | yenagoa
# Processing Record 50 of Set 14 | santa cruz de tenerife
# Processing Record 1 of Set 15 | polyarnyy
# Processing Record 2 of Set 15 | niamey
# Processing Record 3 of Set 15 | puerto escondido
# Processing Record 4 of Set 15 | menongue
# Processing Record 5 of Set 15 | boende
# Processing Record 6 of Set 15 | shenkursk
# Processing Record 7 of Set 15 | la brea
# Processing Record 8 of Set 15 | murdochville
# Processing Record 9 of Set 15 | chifeng
# Processing Record 10 of Set 15 | camacha
# Processing Record 11 of Set 15 | waitara
# Processing Record 12 of Set 15 | tabou
# Processing Record 13 of Set 15 | huangmei
# Processing Record 14 of Set 15 | tigre
# Processing Record 15 of Set 15 | lucapa
# Processing Record 16 of Set 15 | mayskiy
# Processing Record 17 of Set 15 | christchurch
# Processing Record 18 of Set 15 | sechura
# Processing Record 19 of Set 15 | dzhebariki-khaya
# Processing Record 20 of Set 15 | poum
# Processing Record 21 of Set 15 | mao
# Processing Record 22 of Set 15 | vung tau
# Processing Record 23 of Set 15 | abha
# Processing Record 24 of Set 15 | jablunka
# Processing Record 25 of Set 15 | kendari
# Processing Record 26 of Set 15 | teguise
# Processing Record 27 of Set 15 | praia da vitoria
# Processing Record 28 of Set 15 | kloulklubed
# Processing Record 29 of Set 15 | anaconda
# Processing Record 30 of Set 15 | banda aceh
# Processing Record 31 of Set 15 | outram
# Processing Record 32 of Set 15 | mochudi
# Processing Record 33 of Set 15 | mount isa
# Processing Record 34 of Set 15 | hay river
# Processing Record 35 of Set 15 | chapais
# Processing Record 36 of Set 15 | jining
# Processing Record 37 of Set 15 | saint-georges
# Processing Record 38 of Set 15 | padang
# Processing Record 39 of Set 15 | puerto vallarta
# Processing Record 40 of Set 15 | kununurra
# Processing Record 41 of Set 15 | eenhana
# Processing Record 42 of Set 15 | alice springs
# Processing Record 43 of Set 15 | merauke
# Processing Record 44 of Set 15 | agadez
# Processing Record 45 of Set 15 | diamantino
# Processing Record 46 of Set 15 | louisbourg
# 'coord'
# Processing Record 47 of Set 15 | port hueneme
# Processing Record 48 of Set 15 | solnechnyy
# Processing Record 49 of Set 15 | rio cuarto
# Processing Record 50 of Set 15 | divnomorskoye
# Processing Record 1 of Set 16 | innisfail
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Upernavik  72.7868  -56.1549    -14.76        92          27
# 1          Kapaa  22.0752 -159.3190     81.48        70          40
# 2    San Lorenzo -25.3333  -57.5333     76.59        53           0
# 3     Georgetown   5.4112  100.3354     82.33        82          20
# 4        Rikitea -23.1203 -134.9692     78.40        70           2
# 5          Lodja  -3.4833   23.4333     68.45        99         100
# 6  Mar Del Plata -38.0023  -57.5575     69.94        92          75
# 7        Kampene  -3.6000   26.6667     66.02        99         100
# 8           Faya  18.3851   42.4509     45.12        80           1
# 9     Ballinrobe  53.6333   -9.2333     47.75        70         100
#
#    Wind Speed Country
# 0        9.93      GL
# 1        6.91      US
# 2        5.01      PY
# 3        6.91      MY
# 4       14.03      PF
# 5        5.06      CD
# 6       20.00      AR
# 7        1.92      CD
# 8        2.71      SA
# 9       21.23      IE

# %%
print(city_data_df)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Upernavik  72.7868  -56.1549    -14.76        92          27
# 1            Kapaa  22.0752 -159.3190     81.48        70          40
# 2      San Lorenzo -25.3333  -57.5333     76.59        53           0
# 3       Georgetown   5.4112  100.3354     82.33        82          20
# 4          Rikitea -23.1203 -134.9692     78.40        70           2
# ..             ...      ...       ...       ...       ...         ...
# 683   Port Hueneme  34.1478 -119.1951     56.26        88         100
# 684     Solnechnyy  50.7214  136.6319     -1.25        95          94
# 685     Rio Cuarto -33.1307  -64.3499     78.57        38           0
# 686  Divnomorskoye  44.5011   38.1353     25.09        57          46
# 687      Innisfail -17.5333  146.0333     80.83        82         100
#
#      Wind Speed Country
# 0          9.93      GL
# 1          6.91      US
# 2          5.01      PY
# 3          6.91      MY
# 4         14.03      PF
# ..          ...     ...
# 683        5.75      US
# 684        4.14      RU
# 685       13.80      AR
# 686       10.07      RU
# 687        1.92      AU
#
# [688 rows x 8 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
columns
# Out:
# [['City',
#   'Country',
#   'Date',
#   'Lat',
#   'Lng',
#   'Max Temp',
#   'Humidity',
#   'Cloudiness',
#   'Wind Speed']]

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
#cols = city_data_df.columns.tolist("City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description")
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df [['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Upernavik      GL  72.7868  -56.1549    -14.76        92          27
# 1          Kapaa      US  22.0752 -159.3190     81.48        70          40
# 2    San Lorenzo      PY -25.3333  -57.5333     76.59        53           0
# 3     Georgetown      MY   5.4112  100.3354     82.33        82          20
# 4        Rikitea      PF -23.1203 -134.9692     78.40        70           2
# 5          Lodja      CD  -3.4833   23.4333     68.45        99         100
# 6  Mar Del Plata      AR -38.0023  -57.5575     69.94        92          75
# 7        Kampene      CD  -3.6000   26.6667     66.02        99         100
# 8           Faya      SA  18.3851   42.4509     45.12        80           1
# 9     Ballinrobe      IE  53.6333   -9.2333     47.75        70         100
#
#    Wind Speed
# 0        9.93
# 1        6.91
# 2        5.01
# 3        6.91
# 4       14.03
# 5        5.06
# 6       20.00
# 7        1.92
# 8        2.71
# 9       21.23

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv('cities.csv')
